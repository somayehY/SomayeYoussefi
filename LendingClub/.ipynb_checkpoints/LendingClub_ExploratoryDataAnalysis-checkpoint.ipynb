# %% [markdown]
# ### Lending Club: a default ratio prediction study

# %%
# Table of contents

# %% [markdown]
# * [1. Background](#Background)
# * [2. Importing required packages](#Import)
# * [3. Loading the data](#Load)
# * [4. Distribution of Loan status](#Status)
# * [5. Is Charged Off similar to Default?](#ChargedOff)
# * [6. Combining charged off and default loans](#combine)
# * [7. Exploring effects of different featurs on loan status distribution](#explore)
#     * [7.1. Loan status distribution in each year](#year)
#     * [7.2. Loan status distribution vs grade](#grade)
#     * [7.3. Loan status distribution vs home ownership](#home)
#     * [7.4. Loan status distribution vs employment length](#empl)
#     * [7.5. Loan status distribution vs annual income ](#income)
#     * [7.6. Loan status distribution vs low and high ranges of Fico score](#Fico)
#     * [7.7. Loan status distribution vs installment, interest rate and loan amount ](#installment)
#     * [7.8. Loan status distribution vs previous charged off, banckruptcies, collections and tax liens](#tax)
#     * [7.9. Loan status distribution vs utilization rate, revolving balance and inquires within 6 month of loan application](#util)
#     * [7.10. Loan status distribution vs number of open accounts, mortages and number of revolving accounts](#account)

# %% [markdown]
# ## 1. Background <a class='anchor' id='Background'></a>
#
# LendingClub used to be the biggest peer to peer lending platform until 2020, when they changed their business focus. During its operation, LendingClub would establish a platform for borrowers and investors where borrowers were allowed to create loan requests on its website. They were also required to provide their information like credit score, credit history, desired loan amount and the debt-to-income ratio. Based on the data, LendingClub would decide if the loan request would be accepted and what the interest rate would be.
#
# The data is from Kaggle website and can be found here: All Lending Club loan data | Kaggle
#
# The original data file of the accepted loans has 151 columns and more than 2 million rows. During the data wrangling process, any columns that was not established prior to the decision was dropped. The focus is on the single applicants, therefore, join applications were also dropped. Histograms of the distributions of features did not show any abnormalities.

# %% [markdown]
# ## 2. Importing required packages <a class='anchor' id='Import'></a>

# %%
# !pip install -q hvplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import hvplot.pandas

# %% [markdown]
# ## 3. Loading the data <a class='anchor' id='Load'></a>

# %%
# Loading the data:

path = "C:\\Users\\somfl\\Documents\\Data Science Career Track\\LendingClub\\TruncatedData.csv"
df = pd.read_csv(path, sep='\t')

# %%
df.head()
# Out:
#    Unnamed: 0  revol_util    dti  chargeoff_within_12_mths  \
# 0           0        29.7   5.91                       0.0
# 1           1        19.2  16.06                       0.0
# 2           3        11.6  17.06                       0.0
# 3           4        64.5  25.37                       0.0
# 4           5        68.4  10.20                       0.0
#
#    collections_12_mths_ex_med  inq_last_6mths earliest_cr_line  open_acc  \
# 0                         0.0             1.0         Aug-2003       7.0
# 1                         0.0             4.0         Dec-1999      22.0
# 2                         0.0             0.0         Sep-2008      13.0
# 3                         0.0             3.0         Jun-1998      12.0
# 4                         0.0             0.0         Oct-1987       5.0
#
#    mort_acc  annual_inc  ... fico_range_high fico_range_low        id  \
# 0       1.0     55000.0  ...           679.0          675.0  68407277
# 1       4.0     65000.0  ...           719.0          715.0  68355089
# 2       1.0    110000.0  ...           789.0          785.0  66310712
# 3       6.0    104433.0  ...           699.0          695.0  68476807
# 4       0.0     34000.0  ...           694.0          690.0  68426831
#
#   emp_length  home_ownership  num_rev_accts pub_rec_bankruptcies tax_liens  \
# 0  10+ years        MORTGAGE            9.0                  0.0       0.0
# 1  10+ years        MORTGAGE           27.0                  0.0       0.0
# 2  10+ years        MORTGAGE           13.0                  0.0       0.0
# 3    3 years        MORTGAGE           19.0                  0.0       0.0
# 4    4 years            RENT            4.0                  0.0       0.0
#
#    addr_state  issue_year
# 0          PA        2015
# 1          SD        2015
# 2          NJ        2015
# 3          PA        2015
# 4          GA        2015
#
# [5 rows x 29 columns]

# %%
# Dropping the unnamed column
df = df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ## 4. Distribution of Loan status <a class='anchor' id='Status'></a>

# %%
total = len(df)

plt.figure(figsize = (14,6))

g = sns.countplot(x="loan_status", data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status Categories", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# %% [markdown]
# ## 5. Is Charged Off similar to Default? <a class='anchor' id='ChargedOff'> </a>
#
# As it is shown in the above graph only a very small number of loans are default. A question that is raised by looking at the graph is what charged ff means. A google search led us to the lending club webpage https://help.lendingclub.com/hc/en-us/articles/216127747-What-is-the-difference-between-a-loan-that-is-in-default-and-a-loan-that-has-been-charged-off-#:~:text=What%20is%20the%20difference%20between%20a%20loan%20that,no%20longer%20a%20reasonable%20expectation%20of%20further%20payments. Briefly, a default is when the borower is late and charged off happens when the creditors gives up hope on getting the loan back. So default is the beginning of the process which may or may not lead to charge off.
# To investigate deeper, the original data was loaded and default and charged-off loans were compared. New data frames of deafulted and charged-off loans were created. for these loans, the expected return money was estimated by using the funded amount, interest rate and terms. The expected amount was compared with the total payment.
# In both defaulted and charged off loans, the borrower has failed to pay back the loan. For the defaulted loans, the recoveries (which is collected through debt collection or etc after the settlement) are all zero. For charged off loans there are some loans which has recoveries. Only in one case the amount of recoveries is bigger than the expected return. The extra return should happen due to late fees.

# %%
dfCheck = pd.read_csv("C:\\Users\\somfl\\Documents\\Data Science Career Track\\LendingClub\\accepted_2007_to_2018Q4.csv")
# Out:
# C:\Users\somfl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dfDef = dfCheck.loc[dfCheck['loan_status']=='Charged Off', ['total_pymnt', 'funded_amnt', 'loan_amnt', 'id', 'int_rate', 'term', 'recoveries']]
dfDef.sample(10)
# Out:
#          total_pymnt  funded_amnt  loan_amnt         id  int_rate        term  \
# 287500       8781.74      25000.0    25000.0   48695103     17.57   60 months
# 641470        607.11       6000.0     6000.0  111716583     13.59   36 months
# 405126       1510.36       4000.0     4000.0   38659096     15.99   36 months
# 2226248      6265.45      10000.0    10000.0   92339281     13.49   36 months
# 607887       7692.36      19000.0    19000.0  114781469      7.21   36 months
# 152107       3928.31      12800.0    12800.0   59601587     13.33   36 months
# 679272      11280.15      16950.0    16950.0   79562245      8.39   36 months
# 231660       8802.82       9800.0     9800.0   54037837     12.29   36 months
# 2133802      6463.39      24000.0    24000.0  120462733     12.62   60 months
# 149892       7050.96      10000.0    10000.0   59472659     12.69   36 months
#
#          recoveries
# 287500         0.00
# 641470         0.00
# 405126       529.64
# 2226248      843.98
# 607887         0.00
# 152107         0.00
# 679272      1138.06
# 231660      2279.00
# 2133802        0.00
# 149892       356.06

# %%
dfDef['diff'] = dfDef['total_pymnt'] - dfDef['loan_amnt']*((100+dfDef['int_rate'])/100)**(36/12)
dfDef.loc[dfDef['diff']>0].sort_values(by = ['diff'])
# Out:
#          total_pymnt  funded_amnt  loan_amnt        id  int_rate        term  \
# 2258284     23439.24      10800.0    10800.0  90835542     19.99   36 months
#
#          recoveries         diff
# 2258284    23439.24  4781.505211

# %%
dfDef2 = dfCheck.loc[dfCheck['loan_status']=='Default', ['total_pymnt', 'funded_amnt', 'loan_amnt', 'id', 'int_rate', 'term', 'recoveries']]
dfDef2['diff'] = dfDef2['total_pymnt'] - dfDef2['loan_amnt']*((100+dfDef2['int_rate'])/100)**(36/12)
dfDef2.sample(10)
# Out:
#          total_pymnt  funded_amnt  loan_amnt         id  int_rate        term  \
# 492124       2325.65      10000.0    10000.0  127591076     19.03   60 months
# 1207115     13942.05      12000.0    12000.0   24776849     12.49   60 months
# 612391       8587.99      16000.0    16000.0  113205962      7.97   36 months
# 2122476      3004.86      10000.0    10000.0  121279189     13.59   60 months
# 1734732      6132.66       8000.0     8000.0   96826488     12.74   36 months
# 1524260      2263.81      15000.0    15000.0  133794246     17.47   60 months
# 693239       4302.76       4000.0     4000.0   79074327     11.47   36 months
# 1485333      1865.45       6000.0     6000.0  135800419     18.45   36 months
# 839321        339.77       3500.0     3500.0  137067346     11.06   36 months
# 2243385      7008.58       8400.0     8400.0   91643221     14.99   36 months
#
#          recoveries          diff
# 492124          0.0 -14538.688113
# 1207115         0.0  -3139.331655
# 612391          0.0 -11550.610505
# 2122476         0.0 -11651.303413
# 1734732         0.0  -5331.020631
# 1524260         0.0 -22051.071946
# 693239          0.0  -1237.549094
# 1485333         0.0  -8105.957057
# 839321          0.0  -4454.704927
# 2243385         0.0  -5763.437590

# %%
dfDef2['recoveries'].value_counts()
# Out:
# 0.0    40
# Name: recoveries, dtype: int64

# %% [markdown]
# ## 6. Combining charged off and default loans and dropping current loans <a  class='anchor' id='combine'></a>
#
# As discussed earlier, charged off and default both refe to a borrower's failiure to return the loan. Therefore, the two status can be combined. Also, loans with _Current_ status, cannot be used in training models, therefore, they will be dropped.

# %%
# Defining a new column 'new_status' and combine 'Charged Off' and 'Default' as well as any 'late' loans into one status

df['new_status'] = df['loan_status']
df.loc[df['loan_status']=='Late (31-120 days)', 'new_status'] = 'Default'
df.loc[df['loan_status']=='In Grace Period', 'new_status'] = 'Default'
df.loc[df['loan_status']=='Late (16-30 days)', 'new_status'] = 'Default'
df.loc[df['loan_status']=='Charged Off', 'new_status'] = 'Default'

#Dropping loans which are 'Current'

s = df[df['loan_status']=='Current'].index
df.drop(s, inplace=True)

# %% [markdown]
# After making the changes to the status, a countplot of the loan status is plotted again.

# %%
# Plotting a countplot of the loan status.

total = len(df)

plt.figure(figsize = (8,6))

g = sns.countplot(x="new_status", data=df)
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status Categories", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# %% [markdown]
# ## 7. Exploring effects of different featurs on loan status distribution <a class='anchor' id='explore'></a>
#
# Now that the data is divided into Fully-paid and default categories, we can start exploring the effect of different features on loans.

# %% [markdown]
# ### 7.1.  Loan status distribution in each year <a class='anchor' id='year'></a>

# %%
defaulL= df.loc[df['new_status']=='Default', ['issue_year']].value_counts()
fullL= df.loc[df['new_status']=='Fully Paid', ['issue_year']].value_counts()
type(fullL)
s = pd.DataFrame({'Default': defaulL, 'Fully Paid': fullL})
s.index=['2012', '2013', '2014', '2015', '2016', '2017', '2018']
fig, ax = plt.subplots(figsize=(10,8))
ax.bar(s.index, s['Fully Paid'])
ax.bar(s.index, s['Default'], bottom=s['Fully Paid'])
ax.set_xticklabels(s.index)
ax.set_ylabel('count')
ax.legend(['Fully Paid', 'Default'])
plt.show()
# Out:
# <ipython-input-326-f29ac795df2e>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index)

# %% [markdown]
# ### 7.2. Loan status distribution vs grade <a class='anchor' id='grade'></a>

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['sub_grade']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['sub_grade']].value_counts()})
s.index=['A1','A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4',
                                            'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3',
                                            'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']
fig, ax = plt.subplots(figsize=(12,8))
ax.bar(s.index, s['Fully Paid'])
ax.bar(s.index, s['Default'], bottom=s['Fully Paid'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid', 'Default'])
plt.show()
# Out:
# <ipython-input-327-262f9468320b>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %% [markdown]
# ### 7.3. Loan status distribution vs home ownership <a class='anchor' id='home' ></a>

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['home_ownership']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['home_ownership']].value_counts()})
s.index=[ 'Any', 'Mortage', 'None', 'Other', 'Own', 'Rent']
fig, ax = plt.subplots(figsize=(12,8))
ax.bar(s.index, s['Fully Paid'])
ax.bar(s.index, s['Default'], bottom=s['Fully Paid'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid', 'Default'])
plt.show()
# Out:
# <ipython-input-328-36faecc868d9>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %% [markdown]
# ### 7.4. Loan status distribution vs employment length <a class='anchor' id='empl' ></a>

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['emp_length']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['emp_length']].value_counts()})
listIndex = s.index
new = []
for item in listIndex:
    new.append(''.join(item))
s.index = new

s = s.reindex(['< 1 year', '1 year', '2 years', '3 years', '4 years', '5 years', '6 years',
    '7 years', '8 years', '9 years', '10+ years'])

fig, ax = plt.subplots(figsize=(12,8))
ax.bar(s.index, s['Fully Paid'])
ax.bar(s.index, s['Default'], bottom=s['Fully Paid'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid', 'Default'])
plt.show()
# Out:
# <ipython-input-398-8430bd7a9c6a>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %% [markdown]
# ### 7.5. Loan status distribution vs annual income <a class='anchor' id='income'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8)) # create 1x2 array of subplots

sns.histplot(x="annual_inc", hue='new_status', bins=30, data=df[df['annual_inc'] < 500000], ax=axes[0])
sns.boxplot(x="new_status", y='annual_inc', data=df[df['annual_inc'] < 500000], ax=axes[1])

plt.show()

# %% [markdown]
# ### 7.6. Loan status distribution vs Fico score <a class='anchor' id='Fico'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (10,6)) # create 1x2 array of subplots

sns.boxplot(y='fico_range_low', x='new_status', data=df, ax=axes[0]) # add boxplot to 1st subplot
sns.boxplot(y='fico_range_high', x='new_status', data=df, ax=axes[1]) # add boxplot to 2nd subplot
# etc.
plt.subplots_adjust(hspace = .4,top = .8)
plt.show()

# %% [markdown]
# ### 7.7. Loan status distribution vs installment, interest rate and loan amount <a class='anchor' id='installment'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,10)) # create 1x2 array of subplots

sns.boxplot(x="new_status", y='installment', data=df, ax=axes[0]) # add boxplot to 1st subplot
sns.boxplot(x="new_status", y='int_rate', data=df, ax=axes[1]) # add boxplot to 2nd subplot
sns.boxplot(x="new_status", y='funded_amnt', data=df, ax=axes[2])
sns.countplot(x="term", hue="new_status", data=df, ax=axes[3])
#sns.countplot(x="new_status", y='term', data=df, ax=axes[3])
plt.show()

# %%
sns.scatterplot(y='installment', hue="new_status", y='installment', data=df, ax=axes[0])

# %% [markdown]
# ### 7.8. Loan status distribution vs previous charged off, banckruptcies, collections and tax liens  <a class='anchor' id='tax'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16,8)) # create 1x2 array of subplots

sns.boxplot(x="new_status", y='pub_rec_bankruptcies', data=df, ax=axes[0]) # add boxplot to 1st subplot
sns.boxplot(x="new_status", y='tax_liens', data=df, ax=axes[1]) # add boxplot to 2nd subplot
sns.boxplot(x="new_status", y='collections_12_mths_ex_med', data=df, ax=axes[2])
sns.boxplot(x="new_status", y='chargeoff_within_12_mths', data=df, ax=axes[3])
# etc.
plt.show()

# %% [markdown]
# ### 7.9. Loan status distribution vs utilization rate, revolving balance and inquires within 6 month of loan application  <a class='anchor' id='util'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,8)) # create 1x2 array of subplots

sns.boxplot(x="new_status", y='revol_util', data=df, ax=axes[0]) # add boxplot to 1st subplot
sns.boxplot(x="new_status", y='inq_last_6mths', data=df, ax=axes[1]) # add boxplot to 2nd subplot
sns.boxplot(x="new_status", y='revol_bal', data=df, ax=axes[2])
plt.show()

# %% [markdown]
# ### 7.10. Loan status distribution vs number of open accounts, mortages and number of revolving accounts  <a class='anchor' id='account'></a>

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(16,8)) # create 1x3 array of subplots

sns.boxplot(x="new_status", y='open_acc', data=df, ax=axes[0]) # add boxplot to 1st subplot
sns.boxplot(x="new_status", y='mort_acc', data=df, ax=axes[1]) # add boxplot to 2nd subplot
sns.boxplot(x="new_status", y='num_rev_accts', data=df, ax=axes[2])
plt.show()

# %%
import datetime

# %%
df['Credit Length (year)'] = (pd.to_datetime(df['issue_d'])-pd.to_datetime(df['earliest_cr_line']))/np.timedelta64(1,'Y')

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8)) # create 1x2 array of subplots

sns.histplot(x="Credit Length (year)", hue='new_status', bins=30, data=df, ax=axes[0])
sns.boxplot(x="new_status", y='Credit Length (year)', data=df, ax=axes[1])

plt.show()

# %%
plt.figure()
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16,8)) # create 1x2 array of subplots

sns.histplot(x="dti", hue='new_status', bins=30, data=df, ax=axes[0])
sns.boxplot(x="new_status", y='dti', data=df, ax=axes[1])

plt.show()

# %%
df.columns
# Out:
# Index(['revol_util', 'dti', 'chargeoff_within_12_mths',
#        'collections_12_mths_ex_med', 'inq_last_6mths', 'earliest_cr_line',
#        'open_acc', 'mort_acc', 'annual_inc', 'issue_d', 'sub_grade',
#        'funded_amnt', 'loan_status', 'installment', 'int_rate',
#        'verification_status', 'term', 'revol_bal', 'fico_range_high',
#        'fico_range_low', 'id', 'emp_length', 'home_ownership', 'num_rev_accts',
#        'pub_rec_bankruptcies', 'tax_liens', 'addr_state', 'issue_year',
#        'new_status', 'Credit Length', 'new_issue', 'Credit Length (year)'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(10,15))
sns.countplot(y="addr_state",hue='new_status', ax=ax, data=df)
plt.show()

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['addr_state']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['addr_state']].value_counts()})
listIndex = s.index
new = []
for item in listIndex:
    new.append(''.join(item))
s.index = new
print(new)
#s = s.reindex(['< 1 year', '1 year', '2 years', '3 years', '4 years', '5 years', '6 years',
 #   '7 years', '8 years', '9 years', '10+ years'])

fig, ax = plt.subplots(figsize=(20,15))
ax.bar(s.index, s['Fully Paid'])
ax.bar(s.index, s['Default'], bottom=s['Fully Paid'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid', 'Default'])
plt.show()
# Out:
# ['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']
# <ipython-input-402-08c6fd2f649b>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['addr_state']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['addr_state']].value_counts()})
listIndex = s.index
new = []
for item in listIndex:
    new.append(''.join(item))
s.index = new

path = "C:\\Users\\somfl\\Documents\\Data Science Career Track\\LendingClub\\population.csv"
population = pd.read_csv(path, sep ='\t')
population.drop(['Unnamed: 0'], axis=1, inplace=True)

s = s.join(population.set_index('addr_state'), how='inner')

s['Default_per_10,000'] = s['Default']/ss['population']*10000
s['FullyPaid_per_10,000'] = s['Fully Paid']/ss['population']*10000


fig, ax = plt.subplots(figsize=(20,15))
ax.bar(s.index, s['FullyPaid_per_10,000'])
ax.bar(s.index, s['Default_per_10,000'], bottom=s['FullyPaid_per_10,000'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid per 10,000', 'Default per 10,000'])
plt.show()
# Out:
# <ipython-input-520-7cecccdcb855>:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['addr_state']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['addr_state']].value_counts()})
listIndex = s.index
new = []
for item in listIndex:
    new.append(''.join(item))
s.index = new

path = "C:\\Users\\somfl\\Documents\\Data Science Career Track\\LendingClub\\population.csv"
population = pd.read_csv(path, sep ='\t')
population.drop(['Unnamed: 0'], axis=1, inplace=True)

s = s.join(population.set_index('addr_state'), how='inner')

s['Default_per_10,000'] = s['Default']/ss['population']*10000
s['FullyPaid_per_10,000'] = s['Fully Paid']/ss['population']*10000

s['Default%_per_10,000'] = s['Default_per_10,000']/(s['Default_per_10,000'] + s['FullyPaid_per_10,000'])*100
s['FullyPaid%_per_10,000'] = s['FullyPaid_per_10,000']/(s['Default_per_10,000'] + s['FullyPaid_per_10,000'])*100

fig, ax = plt.subplots(figsize=(20,10))
ax.bar(s.index, s['FullyPaid%_per_10,000'])
ax.bar(s.index, s['Default%_per_10,000'], bottom=s['FullyPaid%_per_10,000'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid per 10,000', 'Default per 10,000'])
plt.show()
# Out:
# <ipython-input-523-e467b3cd176f>:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %%
s.loc[s.index=='IA', :]
# Out:
#     Default  Fully Paid state  population  Default_per_10,000  \
# IA        1           1  Iowa   3104235.0            0.003221
#
#     FullyPaid_per_10,000  Default%_per_10,000  FullyPaid%_per_10,000
# IA              0.003221                 50.0                   50.0

# %%
s = pd.DataFrame({'Default': df.loc[df['new_status']=='Default', ['addr_state']].value_counts(), 'Fully Paid': df.loc[df['new_status']=='Fully Paid', ['addr_state']].value_counts()})
listIndex = s.index
new = []
for item in listIndex:
    new.append(''.join(item))
s.index = new

s['Default%'] = s['Default']/(s['Default'] + s['Fully Paid'])*100
s['Fully Paid%'] = s['Fully Paid']/(s['Default'] + s['Fully Paid'])*100

fig, ax = plt.subplots(figsize=(20,10))
ax.bar(s.index, s['Fully Paid%'])
ax.bar(s.index, s['Default%'], bottom=s['Fully Paid%'])
ax.set_xticklabels(s.index, rotation=45)
ax.set_ylabel('count')
ax.legend(['Fully Paid per 10,000', 'Default per 10,000'])
plt.show()
# Out:
# <ipython-input-532-e0650b3977bb>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(s.index, rotation=45)

# %%
#Code task 1#
#Create a new dataframe, `state_summary_scale` from `state_summary` whilst setting the index to 'state'
df_scale = state_summary.set_index("state")
#Save the state labels (using the index attribute of `state_summary_scale`) into the variable 'state_summary_index'
state_summary_index = state_summary_scale.index
#Save the column names (using the `columns` attribute) of `state_summary_scale` into the variable 'state_summary_columns'
state_summary_columns = state_summary_scale.columns
state_summary_scale.head()

state_summary_scale = scale(state_summary_scale)

state_pca = PCA().fit(state_summary_scale)
state_pca.explained_variance_ratio_

#Code task 6#
#Call the `cumsum()` method on the 'explained_variance_ratio_' attribute of `state_pca` and
#create a line plot to visualize the cumulative explained variance ratio with number of components
#Set the xlabel to 'Component #', the ylabel to 'Cumulative ratio variance', and the
#title to 'Cumulative variance ratio explained by PCA components for state/resort summary statistics'
#Hint: remember the handy ';' at the end of the last plot call to suppress that untidy output
plt.subplots(figsize=(10, 6))
plt.plot(state_pca.explained_variance_ratio_.cumsum())
plt.xlabel('Component #')
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components for state/resort summary statistics');


#Code task 7#
#Call `state_pca`'s `transform()` method, passing in `state_summary_scale` as its argument
state_pca_x = state_pca.transform(state_summary_scale)


x = state_pca_x[:, 0]
y = state_pca_x[:, 1]
state = state_summary_index
pc_var = 100 * state_pca.explained_variance_ratio_.cumsum()[1]
plt.subplots(figsize=(10,8))
plt.scatter(x=x, y=y)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'Ski states summary PCA, {pc_var:.1f}% variance explained')
for s, x, y in zip(state, x, y):
    plt.annotate(s, (x, y))
